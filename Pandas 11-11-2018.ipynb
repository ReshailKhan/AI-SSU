# %%
# series dataframe
import pandas as pd
from pandas import DataFrame, Series
data=pd.read_csv("data for panda exercise.csv")
data
# Out:
#      Student_Code  Degree                    Student_Name  Mid  Quiz1  Quiz2  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28    8.0    3.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17    NaN    5.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18    5.0    2.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14    7.0    2.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27    7.0    6.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25    9.0    6.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28    5.0    6.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26    9.0    6.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19    9.0    4.0
# 9   022-14-110599  BS(CS)                         Arsalan   28    8.0    6.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30    8.0    7.0
# ...

# %%
data[(data.Best_of_Quizzes == 9) & (data.Grade=='A')]
# Out:
#      Student_Code  Degree       Student_Name  Mid  Quiz1  Quiz2  \
# 7   022-14-110388  BS(CS)   Aneebullah Niazi   26    9.0    6.0
# 19  022-14-110222  BS(CS)    Mohammad Hunain   27    9.0    6.0
# 25  022-14-110105  BS(CS)     Muhammad Faraz   26    9.0    6.0
# 34  022-14-110413  BS(CS)   Nazeer Bin Zafar   25    9.0    6.0
# 40  022-14-110584  BS(CS)        Sharif Taqi   27    9.0    6.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27    9.0    6.0
#
#     Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 7                 9          8.0         10.0                   10
# 19                9          8.0         10.0                   10
# 25                9          8.0         10.0                   10
# 34                9          8.0         10.0                   10
# 40                9          8.0         10.0                   10
# 45                9          9.0          NaN                    9
#
# ...

# %%
data[(data.Student_Name.str.startswith("A") ) & (data.Grade=='A')]
# Out:
#     Student_Code  Degree      Student_Name  Mid  Quiz1  Quiz2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26    9.0    6.0
# 9  022-14-110599  BS(CS)           Arsalan   28    8.0    6.0
#
#    Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 7                9          8.0         10.0                   10
# 9                8          8.0          NaN                    8
#
#    Total_Sessional_(50)  Final_(50)  Total(100) Grade
# 7                    45        40.0          85     A
# 9                    44        40.0          84     A

# %%
data[(data.Student_Name.str.contains("Ali"))]
# Out:
#      Student_Code  Degree        Student_Name  Mid  Quiz1  Quiz2  \
# 3    022-14-19718  BS(CS)      Ahmed Ali Raza   14    7.0    2.0
# 4   022-14-110648  BS(CS)     Ahsan Ali Vohra   27    7.0    6.0
# 6   022-14-110588  BS(CS)       Anas Ali Khan   28    5.0    6.0
# 23   022-14-19983  BS(CS)  Muhammad Ali Iqbal   26    5.0    NaN
#
#     Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 3                 7          NaN          2.0                    2
# 4                 7          7.0          9.0                    9
# 6                 6          8.0         10.0                   10
# 23                5          8.0         10.0                   10
#
#     Total_Sessional_(50)  Final_(50)  Total(100) Grade
# 3                     23        23.0          46     F
# 4                     43        34.0          77     B
# 6                     44        30.0          74     B
# 23                    41        21.0          62     C

# %%
data[(data.Student_Name.str.contains(" Ali"))]
# Out:
#      Student_Code  Degree        Student_Name  Mid  Quiz1  Quiz2  \
# 3    022-14-19718  BS(CS)      Ahmed Ali Raza   14    7.0    2.0
# 4   022-14-110648  BS(CS)     Ahsan Ali Vohra   27    7.0    6.0
# 6   022-14-110588  BS(CS)       Anas Ali Khan   28    5.0    6.0
# 23   022-14-19983  BS(CS)  Muhammad Ali Iqbal   26    5.0    NaN
#
#     Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 3                 7          NaN          2.0                    2
# 4                 7          7.0          9.0                    9
# 6                 6          8.0         10.0                   10
# 23                5          8.0         10.0                   10
#
#     Total_Sessional_(50)  Final_(50)  Total(100) Grade
# 3                     23        23.0          46     F
# 4                     43        34.0          77     B
# 6                     44        30.0          74     B
# 23                    41        21.0          62     C

# %%
data=pd.read_csv("Election data 2018.csv")
data
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
data.shape
# Out:
# (3167, 5)

# %%
data.size
# Out:
# 15835

# %%
data.groupby("Constituency_title")["Party"].count().nlargest(5)
# Out:
# Constituency_title
# NA-45     39
# NA-48     35
# NA-53     33
# NA-259    31
# NA-50     28
# Name: Party, dtype: int64

# %%
data.groupby(["Party"]).count()
# Out:
#                                          District  Seat  Constituency_title  \
# Party
#                                                 1     1                   1
# ALL PAKISTAN MUSLIM LEAGUE                      1     1                   1
# Aam Admi Tehreek Pakistan                       1     1                   1
# Aam Awam Party                                  2     2                   2
# Aam Log Party Pakistan                          4     4                   4
# All Pakistan Mishit) League                     1     1                   1
# All Pakistan Muslim League                     33    33                  33
# All Pakistan Muslim League                      6     6                   6
# All Pakistan Muslim League (Jinnah)             1     1                   1
# All Pakistan Muslim League(Jinnah)              1     1                   1
# All Pakistan Muslim league                      1     1                   1
# ...

# %%
import pandas as pd
from fuzzywuzzy import fuzz as f
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-57-4e2c801738ee> in <module>()
#       1 import pandas as pd
# ----> 2 from fuzzywuzzy import fuzz as f
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'

# %%
data[data.Party=="Allah-o-Akbar Tehreek"].count()
# Out:
# District              27
# Seat                  27
# Constituency_title    27
# Candidate_Name        27
# Party                 27
# dtype: int64

# %%
data[data.Party=="Allah-o-Akbar Tehreek"]
# Out:
#                     District                   Seat Constituency_title  \
# 29                      Swat               Swat-III               NA-4
# 53                 Lower Dir            Lower Dir-I               NA-6
# 64                 Lower Dir           Lower Dir-II               NA-7
# 143   Mnnsehra? culn Torghar                Torghar             NA? 14
# 1152               Sargodha            Sargodha-lll              NA-90
# 1162               Sargodha             Sargodha-lV              NA-91
# 1238                 Chiniot              Chiniot-l              NA-99
# 1257                 Chiniot             Chiniot-ll             NA-100
# 1261              Faisalabad           Faisalabad-l             NA-101
# 1281              Faisalabad          faisalabad-ll             NA-102
# 1297              Faisalabad         faisalabad-lll             NA-103
# 1307              Faisalabad          faisalabad-lV             NA-104
# ...

# %%
data[data.Candidate_Name=="Faisal Nadeem Shaikh"]
# Out:
#        District            Seat Constituency_title        Candidate_Name  \
# 2461  Hyderabad    Hyderabad-II             NA-226  Faisal Nadeem Shaikh
# 2812   Karachi   Karachi West-V             NA-252  Faisal Nadeem Shaikh
#
#                            Party
# 2461       Allah-o-Akbar Tehreek
# 2812  Pakistan Muslim League (N)

# %%
data[data.Party.]
